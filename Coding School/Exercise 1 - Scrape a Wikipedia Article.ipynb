# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import pandas as pd
import os

import warnings
warnings.filterwarnings('ignore')

# %%
filepath = 'Fill This In'
print('Path to Driver is '+filepath)
browser=webdriver.Chrome(executable_path=filepath)
# Out:
# Path to Driver is C:\Users\COBENA\Desktop\Learn\Code\FTW\Capstone\Automotive\Web Scraping\chromedriver.exe

# %%
#create a dataframe to store all the information here
'dataframe'

#Fill out the link to tell chrome to go to the url inside the parenthesis
browser.get('Fill This In')

#create a for loop to get the information inside the table using xpath
for row in range('number of rows'):
    topic = browser.find_element_by_xpath('Fill This In').text
    value = browser.find_element_by_xpath('Fill This In').text
    
    #create a dictionary so you can store the information of the two items topic and value
    record={'Fill This In'}
    
    #create a list to organize the sequence of the columns of the dataframe since dictionaries are not sequential
    order_list = ['Fill This In']
    
    #append the information into your dataframe
    df = df.append(record, ignore_index=True)
    
    #sort the order based on the list
    df = df[order_list]

#replace the \n values with a comma. Make sure inplace is True
df.replace(to_replace='\n',value=', ', regex=True, inplace=True)
df

######################### BONUS: SAVE THE FILE #########################
try:
    #name of the file. You can also specify a location
    savepath = "Fill This In"
    
    #save the dataframe into a csv file
    wiki = df.to_csv(savepath, index=None, header=False)
    
    #notifier that the whole loop is complete
    print('done')
    
except Exception as e:
    
    #if the saving fails, it will print the reason for the error below
    print ("Export exception:", e)
# Out:
# Developer(s) = Valve Corporation
# Publisher(s) = Valve Corporation
# Designer(s) = IceFrog
# Writer(s) = Marc Laidlaw
# Ted Kosmatka
# Kris Katz
# Composer(s) = Jason Hayes
# Tim Larkin
# Engine = Source 2
# Platform(s) = Microsoft Windows
# Linux
# OS X
# Release = Windows
# July 9, 2013
# Linux, OS X
# July 18, 2013
# Genre(s) = MOBA
# Mode(s) = Multiplayer
#           topic                                              value
# 0  Developer(s)                                  Valve Corporation
# 1  Publisher(s)                                  Valve Corporation
# 2   Designer(s)                                            IceFrog
# 3     Writer(s)              Marc Laidlaw, Ted Kosmatka, Kris Katz
# 4   Composer(s)                            Jason Hayes, Tim Larkin
# 5        Engine                                           Source 2
# 6   Platform(s)                     Microsoft Windows, Linux, OS X
# 7       Release  Windows, July 9, 2013, Linux, OS X, July 18, 2013
# 8      Genre(s)                                               MOBA
# 9       Mode(s)                                        Multiplayer
